# %%
your_local_path="Mcintosh HD/Users/rk/Desktop/UP X TECH/Projects/Project Datasets/Proj_NYC-Flight_data"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
cd /users/rk/Desktop/UP X TECH/Projects/Project Datasets/Proj_NYC-Flight_data
# Out:
# /Users/rk/Desktop/UP X TECH/Projects/Project Datasets/Proj_NYC-Flight_data

# %%
pd.read_csv("flight_data.csv")
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 6       2013      1    1     555.0             600       -5.0     913.0
# 7       2013      1    1     557.0             600       -3.0     709.0
# 8       2013      1    1     557.0             600       -3.0     838.0
# 9       2013      1    1     558.0             600       -2.0     753.0
# 10      2013      1    1     558.0             600       -2.0     849.0
# 11      2013      1    1     558.0             600       -2.0     853.0
# ...

# %%
import numpy as np
import pandas as pd
#Airlines = pd.read_csv(your_local_path+'cars.csv')
Airlines = pd.read_csv("flight_data.csv")

# dataframe structure
type(Airlines)
Airlines.head(10)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
# 5  2013      1    1     554.0             558       -4.0     740.0
# 6  2013      1    1     555.0             600       -5.0     913.0
# 7  2013      1    1     557.0             600       -3.0     709.0
# 8  2013      1    1     557.0             600       -3.0     838.0
# 9  2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# ...

# %%
Airlines.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# ...

# %%
#(1) Departure delay

# %%
max_dep_delay = Airlines.iloc[:,5].max()
idx = Airlines[Airlines['dep_delay'] == max_dep_delay]
print(idx[['dep_delay','flight','carrier']])

print("-------------------------------------")

#delay departure count data
Airlines = Airlines[(Airlines['dep_delay'] > 0)]
print ('Delay departure count: ',Airlines['dep_delay'].count())
# Out:
#       dep_delay  flight carrier
# 7072     1301.0      51      HA
# -------------------------------------
# Delay departure count:  128432

# %%
#(2)Best Airports in terms of time departure%

# %%
Airlines[Airlines.iloc[:,3] == Airlines.iloc[:,3].max()]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 54966   2013     10   30    2400.0            2359        1.0     327.0
# 80973   2013     11   27    2400.0            2359        1.0     515.0
# 87893   2013     12    5    2400.0            2359        1.0     427.0
# 91492   2013     12    9    2400.0            2359        1.0     432.0
# 91493   2013     12    9    2400.0            2250       70.0      59.0
# 95379   2013     12   13    2400.0            2359        1.0     432.0
# 100795  2013     12   19    2400.0            2359        1.0     434.0
# 109532  2013     12   29    2400.0            1700      420.0     302.0
# 117373  2013      2    7    2400.0            2359        1.0     432.0
# 117374  2013      2    7    2400.0            2359        1.0     443.0
# 120677  2013      2   11    2400.0            2135      145.0     251.0
# 150301  2013      3   15    2400.0            2359        1.0     324.0
# ...

# %%
#(3) Aircraft speed analysis

# %%
Airlines[['distance']].count()
Airlines[['hour']].count()

#speed analysis in mile

Airlines['speed'] = Airlines.loc[:,'distance']/(Airlines.loc[:,'hour']*60 + Airlines.loc[:,'minute'])*60
Airlines.head()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-96-476c23c468e0> in <module>()
#       4 #speed analysis in mile
#       5
# ----> 6 Airlines['speed'] = Airlines.loc[:,'distance']/(Airlines.loc[:,'hour']*60 + Airlines.loc[:,'minute'])*60
#       7 Airlines.head()
#
# /Users/rk/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1308
#    1309         if type(key) is tuple:
# -> 1310             return self._getitem_tuple(key)
#    1311         else:
#    1312             return self._getitem_axis(key, axis=0)
#
# /Users/rk/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     799
#     800         # no multi-index, so validate all of the indexers
# --> 801         self._has_valid_tuple(tup)
#     802
#     803         # ugly hack for GH #836
#
# ...

# %%
#(4) on time arrival percentage(%) analysis

# %%
# on time arrival percentage
# Delay arrival count data
Airlines = Airlines[(Airlines.loc[:,'arr_delay'] > 0)].groupby(['flight']).size()
Airlines_delay = Airlines.reset_index(name = 'delay_arr_count')

# on time arrival count data
Airlines = Airlines[(Airlines.loc[:,'arr_delay'] == 0)].groupby(['flight']).size()
Airlines_ontime = Airlines_ontime.reset_index(name = 'Ontime_arr_count')

# early arrival data
Airlines = Airlines[(Airlines.loc[:,'arr_delay'] < 0)].groupby(['flight']).size()
Airlines_early = Airlines_early.reset_index(name = 'early_arr_count')

# merge dataset
Airlines = pd.merge(pd.merge(Airlines_delay,Airlines_ontime,on='flight',how='outer'),Airlines_early,on='flight',how='outer')
Airlines
Airlines = Airlines.fillna(0)
Airlines

#On time arrival percentage(%)
Airlines['ontime_arr_percent'] = (Airlines.loc[:,'ontime_arr_count']/(Airlines.loc[:,'delay_arr_count'] 
                         + Airlines.loc[:,'ontime_arr_count'] + Airlines.loc[:,'early_arr_count']))*100
Airlines
pd.set_option('precision',2)
Airlines
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/rk/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1410                 if key not in ax:
# -> 1411                     error()
#    1412             except TypeError as e:
#
# /Users/rk/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1405                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1406                                (key, self.obj._get_axis_name(axis)))
#    1407
#
# KeyError: 'the label [arr_delay] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-fc014a83f5a4> in <module>()
#       1 # on time arrival percentage
#       2 # Delay arrival count data
# ...

# %%
#(5) Maximum number of flight headed to some erticular destination

# %%
Airlines.head(1)
Airlines = Airlines.groupby(['dest']).size()
Airlines = Airlines.reset_index(name = 'tot_flight_dest_count')
Airlines
# Out:
#     dest  tot_flight_dest_count
# 0    ABQ                    115
# 1    ACK                     82
# 2    ALB                    210
# 3    ANC                      6
# 4    ATL                   6081
# 5    AUS                   1037
# 6    AVL                     86
# 7    BDL                    186
# 8    BGR                    153
# 9    BHM                    138
# 10   BNA                   2509
# 11   BOS                   4821
# 12   BQN                    391
# 13   BTV                    964
# 14   BUF                   1684
# 15   BUR                    151
# 16   BWI                    672
# 17   BZN                     15
# 18   CAE                     72
# 19   CAK                    403
# 20   CHO                     19
# 21   CHS                   1043
# 22   CLE                   1706
# 23   CLT                   4279
# 24   CMH                   1192
# 25   CRW                     53
# 26   CVG                   1530
# 27   DAY                    599
# ...
